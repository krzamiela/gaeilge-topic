# %%
#####################
## DATA EXTRACTION ##
#####################

import requests
from bs4 import BeautifulSoup
import re


def get_page(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")
    return soup

    
soup = get_page("https://songsinirish.com/tags/sean-nos/")

# %%
# build link list
links = []
save = 0

for link in soup.findAll("a"):
    # start saving links once at A-Z index
    if "A bhean úd thíos" in link:
        save = 1
    
    if save == 1:
        links.append(link.get('href'))
    
    if "Úrchnoc Chéin Mhic Cáinte" in link:
        save = 0
        
print(len(links))
# Out:
# 468

# %%
# crawl links and scrape text
gaeilge = []

for link in links:
    print('Link: ', link)
    soup = get_page(link)
    
    for text in soup.findAll("script"):
        if "teacs-gaeilge" in str(text):
            gaeilge_text = re.findall(r'(?<=var htmlString = \")(.*)(?=\";)', str(text))
            # remove tags
            gaeilge_clean = re.sub("<[^>]*>", " ", str(gaeilge_text))
            gaeilge.append(gaeilge_clean)
    
print(len(gaeilge))
# Out:
# Link:  https://songsinirish.com/a-bhean-ud-thios-lyrics/
# Link:  https://songsinirish.com/bhean-udai-thall-lyrics/
# Link:  https://songsinirish.com/a-bhride-bheag-chron-lyrics/
# Link:  https://songsinirish.com/a-chomaraigh-aoibhinn-o-lyrics/
# Link:  https://songsinirish.com/a-ghadai-a-ghoid-mo-phiopa-lyrics/
# Link:  https://songsinirish.com/a-mhaire-bhruinneall-lyrics/
# Link:  https://songsinirish.com/a-mhuirnin-og-lyrics/
# Link:  https://songsinirish.com/a-oganaigh-an-chuil-chraobhaigh-lyrics/
# Link:  https://songsinirish.com/a-phaidi-a-ghra-lyrics/
# Link:  https://songsinirish.com/a-phluirin-na-mban-donn-og-lyrics/
# Link:  https://songsinirish.com/a-ri-an-domhnaigh-lyrics/
# Link:  https://songsinirish.com/a-sheain-bhain-lyrics/
# Link:  https://songsinirish.com/a-sheain-mhic-mhurchaidh-lyrics/
# Link:  https://songsinirish.com/a-spailpin-a-run-lyrics/
# Link:  https://songsinirish.com/ag-an-phobal-de-domhnaigh-lyrics/
# Link:  https://songsinirish.com/ag-cuan-bhinn-eadair-lyrics/
# Link:  https://songsinirish.com/ag-goil-frid-bhaile-an-tsratha-domh-lyrics/
# Link:  https://songsinirish.com/ag-siul-chois-na-tra-domh-lyrics/
# Link:  https://songsinirish.com/aililiu-na-gamhna-lyrics/
# Link:  https://songsinirish.com/ainnir-dheas-na-gciabhfholt-donn-lyrics/
# Link:  https://songsinirish.com/aird-ti-chuain-lyrics/
# Link:  https://songsinirish.com/aird-ui-chuain-lyrics/
# Link:  https://songsinirish.com/aisling-gheal-lyrics/
# Link:  https://songsinirish.com/amaireach-la-le-padraig-lyrics/
# Link:  https://songsinirish.com/amarach-la-le-padraic-lyrics/
# Link:  https://songsinirish.com/amhran-an-bhainin-lyrics/
# Link:  https://songsinirish.com/amhran-an-bheet-lyrics/
# Link:  https://songsinirish.com/amhran-an-chait-lyrics/
# Link:  https://songsinirish.com/amhran-an-leictreachais-lyrics/
# Link:  https://songsinirish.com/amhran-an-phoitin-lyrics/
# Link:  https://songsinirish.com/amhran-an-phortaigh-lyrics/
# Link:  https://songsinirish.com/amhran-an-phriosuin-lyrics/
# Link:  https://songsinirish.com/amhran-an-phuca-lyrics/
# Link:  https://songsinirish.com/amhran-an-steamer-lyrics/
# Link:  https://songsinirish.com/amhran-an-tae-lyrics/
# Link:  https://songsinirish.com/amhran-an-tobac-lyrics/
# Link:  https://songsinirish.com/amhran-bhaby-costello-lyrics/
# Link:  https://songsinirish.com/amhran-chamais-lyrics/
# Link:  https://songsinirish.com/amhran-fhoirnise-lyrics/
# Link:  https://songsinirish.com/amhran-johnny-geoghegan-lyrics/
# Link:  https://songsinirish.com/amhran-khildare-lyrics/
# Link:  https://songsinirish.com/amhran-leitir-calaidh-lyrics/
# Link:  https://songsinirish.com/amhran-mhainse-lyrics/
# Link:  https://songsinirish.com/amhran-mhairtin-mhoir-lyrics/
# Link:  https://songsinirish.com/amhran-na-heascainne-lyrics/
# Link:  https://songsinirish.com/amhran-na-leabhar-lyrics/
# Link:  https://songsinirish.com/amhran-na-mbad-lyrics/
# Link:  https://songsinirish.com/amhran-na-mbiollai-lyrics/
# Link:  https://songsinirish.com/amhran-na-mbolman-lyrics/
# Link:  https://songsinirish.com/amhran-na-mianach-lyrics/
# Link:  https://songsinirish.com/amhran-na-n-asal-lyrics/
# Link:  https://songsinirish.com/amhran-na-n-iontas-lyrics/
# Link:  https://songsinirish.com/amhran-na-paise-lyrics/
# Link:  https://songsinirish.com/amhran-na-scadan-lyrics/
# Link:  https://songsinirish.com/amhran-na-seoighigh-lyrics/
# Link:  https://songsinirish.com/amhran-na-smear-lyrics/
# Link:  https://songsinirish.com/amhran-na-speile-lyrics/
# Link:  https://songsinirish.com/amhran-na-tra-baine-lyrics/
# Link:  https://songsinirish.com/amhran-phadraic-dharach-lyrics/
# Link:  https://songsinirish.com/amhran-phead-bhui-lyrics/
# Link:  https://songsinirish.com/amhran-pheadair-bhreathnaigh-lyrics/
# Link:  https://songsinirish.com/amhran-pheait-sheain-ainde-lyrics/
# Link:  https://songsinirish.com/amhran-pheter-mhicil-baille-lyrics/
# Link:  https://songsinirish.com/amhran-rinn-mhaoile-lyrics/
# Link:  https://songsinirish.com/amhran-sheamais-ui-chonchuir-lyrics/
# Link:  https://songsinirish.com/an-abhainn-mhor-lyrics/
# Link:  https://songsinirish.com/an-baitsileir-lyrics/
# Link:  https://songsinirish.com/an-bas-lyrics/
# Link:  https://songsinirish.com/an-bhanaltra-lyrics/
# Link:  https://songsinirish.com/an-bhfaca-tu-mo-sheamaisin-lyrics/
# Link:  https://songsinirish.com/an-bho-bhan-lyrics/
# Link:  https://songsinirish.com/an-bhruinneall-dheas-lyrics/
# Link:  https://songsinirish.com/an-bhruinnillin-bheasach-lyrics/
# Link:  https://songsinirish.com/an-bhuatais-lyrics/
# Link:  https://songsinirish.com/an-binsin-luachra-lyrics/
# Link:  https://songsinirish.com/an-bobaire-lyrics/
# Link:  https://songsinirish.com/an-bonnan-bui-lyrics/
# Link:  https://songsinirish.com/an-brianach-og-lyrics/
# Link:  https://songsinirish.com/an-buachaill-ban-lyrics/
# Link:  https://songsinirish.com/an-buachaill-caol-ard-lyrics/
# Link:  https://songsinirish.com/an-buachaill-deas-og-lyrics/
# Link:  https://songsinirish.com/an-buachaillin-ban-lyrics/
# Link:  https://songsinirish.com/an-buachaillin-muinte-lyrics/
# Link:  https://songsinirish.com/an-buachaillin-speiriuil-lyrics/
# Link:  https://songsinirish.com/an-cailin-aerach/
# Link:  https://songsinirish.com/an-cailin-alainn/
# Link:  https://songsinirish.com/an-cailin-deas-rua-lyrics/
# Link:  https://songsinirish.com/an-cailin-fearuil-fionn-lyrics/
# Link:  https://songsinirish.com/an-cailin-gaelach-lyrics/
# Link:  https://songsinirish.com/an-cailin-rua-lyrics/
# Link:  https://songsinirish.com/an-caiptin-o-maille-lyrics/
# Link:  https://songsinirish.com/an-caiptin-sean-lyrics/
# Link:  https://songsinirish.com/an-caisideach-ban-lyrics/
# Link:  https://songsinirish.com/an-carabhat-lyrics/
# Link:  https://songsinirish.com/an-carraigin-lyrics/
# Link:  https://songsinirish.com/an-chaora-ghlas-lyrics/
# Link:  https://songsinirish.com/an-chead-mhairt-d-fhomhar-lyrics/
# Link:  https://songsinirish.com/an-ciarraioch-mallaithe-lyrics/
# Link:  https://songsinirish.com/an-clar-bog-deil-lyrics/
# Link:  https://songsinirish.com/an-cruiscin-lan-lyrics/
# Link:  https://songsinirish.com/an-deirc-lyrics/
# Link:  https://songsinirish.com/an-deorai-lyrics/
# Link:  https://songsinirish.com/an-dilleachtai-fain-lyrics/
# Link:  https://songsinirish.com/an-draighnean-donn-lyrics/
# Link:  https://songsinirish.com/an-fainne-lyrics/
# Link:  https://songsinirish.com/an-faoitin-lyrics/
# Link:  https://songsinirish.com/an-fear-ceoil-lyrics/
# Link:  https://songsinirish.com/an-fhaoileann-lyrics/
# Link:  https://songsinirish.com/an-fial-athair-donall-lyrics/
# Link:  https://songsinirish.com/an-frag-lyrics/
# Link:  https://songsinirish.com/an-gabha-ceartan-lyrics/
# Link:  https://songsinirish.com/an-gamhain-geal-ban-lyrics/
# Link:  https://songsinirish.com/an-gamhnaichin-lyrics/
# Link:  https://songsinirish.com/an-geata-mor-lyrics/
# Link:  https://songsinirish.com/an-gheadach-da-cru-sa-ghleann-lyrics/
# Link:  https://songsinirish.com/an-ghiobog-lyrics/
# Link:  https://songsinirish.com/an-gleann-i-bhfad-siar-lyrics/
# Link:  https://songsinirish.com/an-goirtin-eornan-lyrics/
# Link:  https://songsinirish.com/an-greasai-lyrics/
# Link:  https://songsinirish.com/an-hide-and-go-seek-lyrics/
# Link:  https://songsinirish.com/an-lacha-bacach-lyrics/
# Link:  https://songsinirish.com/an-mhaighdean-mhara-lyrics/
# Link:  https://songsinirish.com/an-mhaighdean-mhara-anuna-lyrics/
# Link:  https://songsinirish.com/an-paistin-fionn-lyrics-2/
# Link:  https://songsinirish.com/an-paistin-fionn-lyrics/
# Link:  https://songsinirish.com/an-poc-ar-buile/
# Link:  https://songsinirish.com/an-posadh-a-bhi-i-gcana-lyrics/
# Link:  https://songsinirish.com/an-raibh-tu-ar-an-gcarraig-lyrics/
# Link:  https://songsinirish.com/an-raicin-alainn-lyrics/
# Link:  https://songsinirish.com/an-rogaire-dubh-lyrics/
# Link:  https://songsinirish.com/an-sagairtin-lyrics/
# Link:  https://songsinirish.com/an-sagart-o-domhnaill-lyrics/
# Link:  https://songsinirish.com/an-saighdiuir-treigthe-lyrics/
# Link:  https://songsinirish.com/an-saturday-lyrics/
# Link:  https://songsinirish.com/an-sceilpin-draighneach-lyrics/
# Link:  https://songsinirish.com/an-scian-lyrics/
# Link:  https://songsinirish.com/an-seanduine-cam-lyrics/
# Link:  https://songsinirish.com/an-seanduine-doite-lyrics/
# Link:  https://songsinirish.com/an-snaithin-ceireach-lyrics/
# Link:  https://songsinirish.com/an-spailpin-fanach-lyrics2/
# Link:  https://songsinirish.com/an-spailpin-fanach-lyrics/
# Link:  https://songsinirish.com/an-spealadoir-muireann-lyrics/
# Link:  https://songsinirish.com/an-t-amhran-breagach-lyrics/
# Link:  https://songsinirish.com/an-t-iolrach-mor-lyrics/
# Link:  https://songsinirish.com/t-oilean-ur-lyrics/
# Link:  https://songsinirish.com/an-tailliuir-druisiuil-lyrics/
# Link:  https://songsinirish.com/an-toilean-ur-clannad-lyrics/
# Link:  https://songsinirish.com/an-toilean-ur-lyrics/
# Link:  https://songsinirish.com/an-tsailchuach-lyrics/
# Link:  https://songsinirish.com/an-tseanbhean-bhocht-lyrics/
# Link:  https://songsinirish.com/an-tseanbhean-liath-lyrics/
# Link:  https://songsinirish.com/an-tsiog-mhallaithe-lyrics/
# Link:  https://songsinirish.com/an-uair-sin-bhi-an-fear-fada-in-arainn-lyrics/
# Link:  https://songsinirish.com/anach-cuan-lyrics/
# Link:  https://songsinirish.com/aonach-bhearna-na-gaoithe-lyrics/
# Link:  https://songsinirish.com/ar-a-ghabhail-na-chuain-domh-lyrics/
# Link:  https://songsinirish.com/ar-a-ghabhail-go-baile-atha-cliath-domh-lyrics/
# Link:  https://songsinirish.com/ar-eirinn-ni-neosfainn-ce-hi-lyrics/
# Link:  https://songsinirish.com/ar-maidin-de-mairt-lyrics/
# Link:  https://songsinirish.com/arainn-i-bhfad-i-gcein-lyrics/
# Link:  https://songsinirish.com/areir-is-me-ag-machnamh-lyrics/
# Link:  https://songsinirish.com/asal-mhainse-lyrics/
# Link:  https://songsinirish.com/asal-pheadair-ui-laidhe-lyrics/
# Link:  https://songsinirish.com/ba-an-cheathrair-lyrics/
# Link:  https://songsinirish.com/bab-na-gcraobh-lyrics/
# Link:  https://songsinirish.com/bacach-mise-ar-aon-chois-lyrics/
# Link:  https://songsinirish.com/badai-na-scadan-lyrics/
# Link:  https://songsinirish.com/badoirin-thir-an-fhia-lyrics/
# Link:  https://songsinirish.com/baidin-fheilimi-lyrics/
# Link:  https://songsinirish.com/baile-an-roba-lyrics/
# Link:  https://songsinirish.com/baile-bhuirne-lyrics/
# Link:  https://songsinirish.com/baile-deas-ghaoth-saile-lyrics/
# Link:  https://songsinirish.com/bainis-jimin-joe-lyrics/
# Link:  https://songsinirish.com/bainne-an-ghabhair-bhain-lyrics/
# Link:  https://songsinirish.com/barr-an-tsleibhe-lyrics/
# Link:  https://songsinirish.com/beairtlin-an-gadai-lyrics/
# Link:  https://songsinirish.com/beal-atha-hamhnais-lyrics/
# Link:  https://songsinirish.com/beal-atha-na-habhann-lyrics/
# Link:  https://songsinirish.com/bean-an-fhir-rua-lyrics/
# Link:  https://songsinirish.com/bean-an-leanna-lyrics/
# Link:  https://songsinirish.com/bean-an-tseanduine-lyrics/
# Link:  https://songsinirish.com/bean-dubh-ghleanna-lyrics/
# Link:  https://songsinirish.com/bean-phaidin-lyrics/
# Link:  https://songsinirish.com/bean-phaidin-lyrics-celtic-woman/
# Link:  https://songsinirish.com/bean-sleibhe-ag-caoineadh-a-mic-lyrics/
# Link:  https://songsinirish.com/beauty-deas-an-oileain-lyrics/
# Link:  https://songsinirish.com/beidh-aonach-amarach-atlan-lyrics/
# Link:  https://songsinirish.com/beidh-aonach-amarach-lyrics/
# Link:  https://songsinirish.com/beir-beannacht-o-ri-na-haoine-lyrics/
# Link:  https://songsinirish.com/beir-mo-dhuthracht-lyrics/
# Link:  https://songsinirish.com/beiti-saili-deain-lyrics/
# Link:  https://songsinirish.com/bimse-fein-ag-iascaireacht-lyrics/
# Link:  https://songsinirish.com/bo-na-leathadhairce-lyrics/
# Link:  https://songsinirish.com/boithrini-an-lochain-lyrics/
# Link:  https://songsinirish.com/brid-bhan-lyrics/
# Link:  https://songsinirish.com/brid-ni-ghaora-lyrics/
# Link:  https://songsinirish.com/brid-og-ni-mhaille-lyrics/
# Link:  https://songsinirish.com/brid-thomais-mhurcha-lyrics/
# Link:  https://songsinirish.com/bride-ni-scannlain-lyrics/
# Link:  https://songsinirish.com/bridin-lyrics/
# Link:  https://songsinirish.com/bridin-bheasai-lyrics/
# Link:  https://songsinirish.com/bruach-na-cara-leith-lyrics/
# Link:  https://songsinirish.com/bruach-na-carraige-baine-lyrics2/
# Link:  https://songsinirish.com/bruach-na-carraige-baine-lyrics/
# Link:  https://songsinirish.com/buachaill-on-eirne/
# Link:  https://songsinirish.com/cad-e-sin-don-te-sin-lyrics/
# Link:  https://songsinirish.com/caide-sin-don-te-sin-lyrics/
# Link:  https://songsinirish.com/cailin-an-tsleibhe-ruaidh-lyrics/
# Link:  https://songsinirish.com/cailin-deas-cruite-na-mbo-lyrics/
# Link:  https://songsinirish.com/cailin-na-n-urla-donn-lyrics/
# Link:  https://songsinirish.com/cailleach-an-airgid-lyrics/
# Link:  https://songsinirish.com/cailleach-an-airgid-lyrics2/
# Link:  https://songsinirish.com/cailleach-na-scribe-lyrics/
# Link:  https://songsinirish.com/caislean-an-tsleibhe-lyrics/
# Link:  https://songsinirish.com/caislean-ui-neill-lyrics/
# Link:  https://songsinirish.com/caislean-ui-neill-lyrics2/
# Link:  https://songsinirish.com/cait-ni-dhuibhir-lyrics/
# Link:  https://songsinirish.com/caitlin-triall-lyrics/
# Link:  https://songsinirish.com/caoineadh-na-dtri-muire-lyrics/
# Link:  https://songsinirish.com/caoineadh-thomais-ui-dhalaigh-lyrics/
# Link:  https://songsinirish.com/caoirigh-na-japs-lyrics/
# Link:  https://songsinirish.com/carraig-aonair-lyrics/
# Link:  https://songsinirish.com/casadh-an-tsugain-lasairfhiona-lyrics/
# Link:  https://songsinirish.com/casadh-an-tsugain-lyrics/
# Link:  https://songsinirish.com/casadh-an-tsugain-lyrics2/
# Link:  https://songsinirish.com/casam-araon-na-geanna-romhainn-lyrics/
# Link:  https://songsinirish.com/cath-cheim-an-fhia-lyrics/
# Link:  https://songsinirish.com/cathair-na-leige-lyrics/
# Link:  https://songsinirish.com/cead-slan-le-bliain-an-taca-seo-lyrics/
# Link:  https://songsinirish.com/ceaite-an-chuil-chraobhaigh-lyrics/
# Link:  https://songsinirish.com/cearc-agus-coileach-lyrics/
# Link:  https://songsinirish.com/cearta-mhicil-de-hora-lyrics/
# Link:  https://songsinirish.com/ceo-draiochta-lyrics/
# Link:  https://songsinirish.com/cianach-corrach-lyrics/
# Link:  https://songsinirish.com/cibe-fear-in-eirinn-lyrics/
# Link:  https://songsinirish.com/citi-na-gcumann-lyrics/
# Link:  https://songsinirish.com/citi-ni-eadhra-lyrics/
# Link:  https://songsinirish.com/cnoc-leitir-moir-lyrics/
# Link:  https://songsinirish.com/coinleach-glas-an-fhomhair-lyrics/
# Link:  https://songsinirish.com/cois-abha-moire-na-ndeise-lyrics/
# Link:  https://songsinirish.com/cois-abhann-na-sead-lyrics/
# Link:  https://songsinirish.com/condae-mhaigh-eo-lyrics/
# Link:  https://songsinirish.com/crann-ull-lyrics/
# Link:  https://songsinirish.com/criocha-an-oileain-uir-lyrics/
# Link:  https://songsinirish.com/cruach-dhomhnaill-ui-riordain-lyrics/
# Link:  https://songsinirish.com/cuaichin-ghleann-neifinn-lyrics/
# Link:  https://songsinirish.com/cuirt-an-tsruthain-bhui-lyrics/
# Link:  https://songsinirish.com/cuirt-bhaile-nua-lyrics/
# Link:  https://songsinirish.com/cuirt-mhallaithe-dhoire-an-fheich-lyrics/
# Link:  https://songsinirish.com/cuisle-mo-chroi-lyrics/
# Link:  https://songsinirish.com/cul-na-binn-lyrics/
# Link:  https://songsinirish.com/cul-na-cruaiche-lyrics/
# Link:  https://songsinirish.com/cumha-an-fhile-lyrics/
# Link:  https://songsinirish.com/cunla-lyrics/
# Link:  https://songsinirish.com/cunnla-lyrics/
# Link:  https://songsinirish.com/dan-an-bhais-lyrics/
# Link:  https://songsinirish.com/digeas-o-deabhas-lyrics/
# Link:  https://songsinirish.com/doin-du-lyrics/
# Link:  https://songsinirish.com/domhnall-o-maolaine-lyrics/
# Link:  https://songsinirish.com/donal-agus-morag-lyrics/
# Link:  https://songsinirish.com/donall-og-lyrics/
# Link:  https://songsinirish.com/donncha-ban-lyrics/
# Link:  https://songsinirish.com/dulaman-lyrics/
# Link:  https://songsinirish.com/dun-do-shuil-lyrics/
# Link:  https://songsinirish.com/eamonn-an-chnoic-lyrics/
# Link:  https://songsinirish.com/eamonn-mhagaine-lyrics/
# Link:  https://songsinirish.com/eanach-cuain-lyrics/
# Link:  https://songsinirish.com/eascann-bhaile-na-hinse-lyrics/
# Link:  https://songsinirish.com/eibhlin-ni-fhlaithearta-lyrics/
# Link:  https://songsinirish.com/eileanoir-na-run-lyrics/
# Link:  https://songsinirish.com/eirigh-suas-a-stoirin-lyrics/
# Link:  https://songsinirish.com/eistidh-seal-liom-lyrics/
# Link:  https://songsinirish.com/eleanor-a-run-lyrics/
# Link:  https://songsinirish.com/eochaill-lyrics/
# Link:  https://songsinirish.com/eoghainin-o-ragadain-lyrics/
# Link:  https://songsinirish.com/eoghan-coir-lyrics/
# Link:  https://songsinirish.com/frainc-ac-conaola-lyrics/
# Link:  https://songsinirish.com/geaftai-bhaile-bui-lyrics/
# Link:  https://songsinirish.com/ho-bha-in-lyrics/
# Link:  https://songsinirish.com/idir-aird-mhor-is-eochaill-lyrics/
# Link:  https://songsinirish.com/imeacht-na-mbad-lyrics/
# Link:  https://songsinirish.com/inion-a-bhaoghailligh-lyrics/
# Link:  https://songsinirish.com/inion-an-fhaoit-on-ngleann-lyrics/
# Link:  https://songsinirish.com/inis-barr-an-chuain-lyrics/
# Link:  https://songsinirish.com/inis-dhun-ramha-lyrics/
# Link:  https://songsinirish.com/is-buachaill-deas-og-me-lyrics/
# Link:  https://songsinirish.com/is-deas-an-buachaill-fointeach-me-lyrics/
# Link:  https://songsinirish.com/is-fada-o-bhaile-lyrics/
# Link:  https://songsinirish.com/is-measa-liom-brodach-lyrics/
# Link:  https://songsinirish.com/is-ora-a-mhile-gra-lyrics/
# Link:  https://songsinirish.com/is-trua-nach-bhfuil-me-i-sasain-lyrics/
# Link:  https://songsinirish.com/is-trua-nach-bhfuil-me-in-eirinn-lyrics/
# Link:  https://songsinirish.com/is-trua-nach-bhfuil-me-in-eirinn-lyrics2/
# Link:  https://songsinirish.com/jimmy-mo-mhile-stor-lyrics/
# Link:  https://songsinirish.com/johnny-seoighe-lyrics/
# Link:  https://songsinirish.com/la-da-rabhas-ar-fuaidreamh-lyrics/
# Link:  https://songsinirish.com/la-fheile-cailin-lyrics/
# Link:  https://songsinirish.com/la-fheile-padraig-lyrics/
# Link:  https://songsinirish.com/landlady-na-pairte-lyrics/
# Link:  https://songsinirish.com/liam-an-chapaill-bhain-lyrics/
# Link:  https://songsinirish.com/liam-o-raghallaigh-lyrics/
# Link:  https://songsinirish.com/linseach-bhearna-lyrics/
# Link:  https://songsinirish.com/liontar-duinn-an-cruiscin-lyrics/
# Link:  https://songsinirish.com/loch-na-ni-lyrics/
# Link:  https://songsinirish.com/loingis-oir-lyrics/
# Link:  https://songsinirish.com/maidin-alainn-ghreine-lyrics/
# Link:  https://songsinirish.com/maidin-bhog-alainn-lyrics/
# Link:  https://songsinirish.com/maidin-fhomhair-lyrics/
# Link:  https://songsinirish.com/maidin-i-mbearra-lyrics/
# Link:  https://songsinirish.com/maidin-luain-chincise-lyrics/
# Link:  https://songsinirish.com/maili-mhomhar-lyrics/
# Link:  https://songsinirish.com/mailsin-chnoc-an-easa-thoir-lyrics/
# Link:  https://songsinirish.com/mainistir-na-buille-lyrics/
# Link:  https://songsinirish.com/mainistir-na-buille/
# Link:  https://songsinirish.com/maire-bhruinneall-lyrics/
# Link:  https://songsinirish.com/maire-chonnacht-lyrics/
# Link:  https://songsinirish.com/maire-inis-toirc-lyrics/
# Link:  https://songsinirish.com/maire-mhaiseach-lyrics/
# Link:  https://songsinirish.com/maire-mhor-lyrics/
# Link:  https://songsinirish.com/maire-ni-eidhin-lyrics/
# Link:  https://songsinirish.com/maire-ni-ghriofa-lyrics/
# Link:  https://songsinirish.com/maire-ni-mhongain-lyrics/
# Link:  https://songsinirish.com/maire-ni-taidhg-oig-lyrics/
# Link:  https://songsinirish.com/maire-rua-lyrics/
# Link:  https://songsinirish.com/mairin-de-barra-lyrics/
# Link:  https://songsinirish.com/mairin-staunton-lyrics/
# Link:  https://songsinirish.com/mal-bhan-ni-chuileannain-lyrics/
# Link:  https://songsinirish.com/malai-bhan-lyrics/
# Link:  https://songsinirish.com/malai-ni-mhaoileoin-lyrics/
# Link:  https://songsinirish.com/mallai-chroch-shli-lyrics/
# Link:  https://songsinirish.com/mar-mheath-uaim-lyrics/
# Link:  https://songsinirish.com/meilte-cheann-dubhrann-lyrics/
# Link:  https://songsinirish.com/meirioca-lyrics/
# Link:  https://songsinirish.com/mna-bana-bhaile-locha-riach-lyrics/
# Link:  https://songsinirish.com/mna-speiriuil-ros-an-mhil-lyrics/
# Link:  https://songsinirish.com/mo-chairde-gaoil-gur-threig-me-lyrics/
# Link:  https://songsinirish.com/mo-cheallachin-fionn-lyrics2/
# Link:  https://songsinirish.com/mo-cheallachin-fionn-lyrics/
# Link:  https://songsinirish.com/mo-ghile-mear-ucd-lyrics/
# Link:  https://songsinirish.com/mo-ghile-mear-lyrics/
# Link:  https://songsinirish.com/mo-ghille-mear-lyrics/
# Link:  https://songsinirish.com/mo-mhadadh-beag-lyrics/
# Link:  https://songsinirish.com/mo-shlan-beo-soir-lyrics/
# Link:  https://songsinirish.com/mo-thigh-beag-aerach-lyrics/
# Link:  https://songsinirish.com/moirin-na-heaglaise-lyrics/
# Link:  https://songsinirish.com/mal-dubh-an-ghleanna-lyrics/
# Link:  https://songsinirish.com/molly-na-gcuach-ni-chuilleanain-lyrics/
# Link:  https://songsinirish.com/molly-na-gcuach-ni-chuilleanain-atlan-lyrics/
# Link:  https://songsinirish.com/mullaigh-chroithli-lyrics/
# Link:  https://songsinirish.com/murchadh-o-maolain-lyrics/
# Link:  https://songsinirish.com/na-bearta-crua-lyrics/
# Link:  https://songsinirish.com/na-connerys-lyrics/
# Link:  https://songsinirish.com/na-gleannta-lyrics/
# Link:  https://songsinirish.com/na-pratai-dubha-lyrics/
# Link:  https://songsinirish.com/na-tinceiri-lyrics/
# Link:  https://songsinirish.com/nansai-bhan-nic-giobarlai-lyrics/
# Link:  https://songsinirish.com/neainsin-bhan-lyrics/
# Link:  https://songsinirish.com/neansai-walsh-lyrics/
# Link:  https://songsinirish.com/neili-an-bhrollaigh-ghil-lyrics/
# Link:  https://songsinirish.com/neili-bhan-lyrics/
# Link:  https://songsinirish.com/ni-fheicfear-nios-mo-thu-a-mhuirnin-lyrics/
# Link:  https://songsinirish.com/nil-na-la-lyrics/
# Link:  https://songsinirish.com/nil-me-ar-an-mbaile-seo-lyrics/
# Link:  https://songsinirish.com/nion-an-bhaoilligh-lyrics/
# Link:  https://songsinirish.com/noirin-mo-mhian-lyrics/
# Link:  https://songsinirish.com/nora-an-chuil-umair-lyrics/
# Link:  https://songsinirish.com/nora-bhan-lyrics/
# Link:  https://songsinirish.com/nora-ni-chonchuir-bhain-lyrics/
# Link:  https://songsinirish.com/nuair-a-bhi-mise-og-lyrics/
# Link:  https://songsinirish.com/o-cad-e-sin-an-te-sin-lyrics/
# Link:  https://songsinirish.com/o-dheara-sheanduine-lyrics/
# Link:  https://songsinirish.com/ocam-an-phriosuin-lyrics/
# Link:  https://songsinirish.com/si-oakum-a-phriosuin-lyrics/
# Link:  https://songsinirish.com/oilean-dhun-an-oir-lyrics/
# Link:  https://songsinirish.com/oilean-glas-arann-na-naomh-lyrics/
# Link:  https://songsinirish.com/oilean-inis-bearachain-lyrics/
# Link:  https://songsinirish.com/oro-mo-bhaidin-lyrics/
# Link:  https://songsinirish.com/oro-se-do-bheatha-bhaile-lyrics/
# Link:  https://songsinirish.com/pearla-deas-an-chuil-bhain-lyrics/
# Link:  https://songsinirish.com/peigin-audley-lyrics/
# Link:  https://songsinirish.com/peigin-is-peadar-lyrics/
# Link:  https://songsinirish.com/peigin-leitir-moir-lyrics/
# Link:  https://songsinirish.com/peigin-misteal-lyrics/
# Link:  https://songsinirish.com/peigins-peadar-teada-lyrics/
# Link:  https://songsinirish.com/pilib-seimh-o-fathaigh-lyrics/
# Link:  https://songsinirish.com/piopa-ainde-mhoir-lyrics2/
# Link:  https://songsinirish.com/piopa-ainde-mhoir-lyrics/
# Link:  https://songsinirish.com/pluid-dhorcha-leara-lyrics/
# Link:  https://songsinirish.com/pluirin-na-mban-donn-og-lyrics/
# Link:  https://songsinirish.com/preab-san-ol-lyrics2/
# Link:  https://songsinirish.com/preab-san-ol-lyrics/
# Link:  https://songsinirish.com/priosun-chluain-meala-lyrics/
# Link:  https://songsinirish.com/pucan-mhicil-phaidin-lyrics/
# Link:  https://songsinirish.com/pucan-sheain-antaine-lyrics/
# Link:  https://songsinirish.com/raca-brea-mo-chinn-lyrics/
# Link:  https://songsinirish.com/raghadsa-is-mo-cheaiti-lyrics/
# Link:  https://songsinirish.com/raiteachas-na-tairngreacht-lyrics/
# Link:  https://songsinirish.com/raithneach-a-bhean-bheag-lyrics/
# Link:  https://songsinirish.com/reidhcnoc-mna-duibhe-lyrics/
# Link:  https://songsinirish.com/rinn-o-gcuanach-lyrics/
# Link:  https://songsinirish.com/roisin-dubh-lyrics2/
# Link:  https://songsinirish.com/roisin-dubh-lyrics/
# Link:  https://songsinirish.com/ros-an-mhil-cois-cuain-lyrics/
# Link:  https://songsinirish.com/sa-tseanghleann-thiar-ag-tadhg-o-grianna-lyrics/
# Link:  https://songsinirish.com/sadhbh-ni-bhruinnealla-lyrics/
# Link:  https://songsinirish.com/sadhbh-ni-bhruinneallaigh-lyrics/
# Link:  https://songsinirish.com/sagart-na-cuile-baine-lyrics/
# Link:  https://songsinirish.com/sail-og-rua-lyrics/
# Link:  https://songsinirish.com/sailor-lyrics/
# Link:  https://songsinirish.com/sambo-eara-lyrics/
# Link:  https://songsinirish.com/se-fath-mo-bhuartha-lyrics/
# Link:  https://songsinirish.com/seachran-chairn-tsiail-lyrics/
# Link:  https://songsinirish.com/seachran-chearbhaill-lyrics/
# Link:  https://songsinirish.com/seacht-ndolas-na-maighdine-lyrics/
# Link:  https://songsinirish.com/seamas-mac-murchaidh-lyrics/
# Link:  https://songsinirish.com/seamas-na-staile-lyrics/
# Link:  https://songsinirish.com/sean-o-di-lyrics/
# Link:  https://songsinirish.com/seanamhran-na-tra-baine-lyrics/
# Link:  https://songsinirish.com/seicin-an-dole-lyrics/
# Link:  https://songsinirish.com/seimi-eoghainin-dhuibh-lyrics/
# Link:  https://songsinirish.com/seoithin-seo-lyrics/
# Link:  https://songsinirish.com/seoladh-na-ngamhna-lyrics/
# Link:  https://songsinirish.com/si-mhaimeo-i-celtic-woman-lyrics/
# Link:  https://songsinirish.com/si-mhaimeo-i-lyrics/
# Link:  https://songsinirish.com/si-mhaimeo-i-anuna-lyrics/
# Link:  https://songsinirish.com/sicini-bhrid-eamoinn-lyrics/
# Link:  https://songsinirish.com/siun-ni-dhuibhir-lyrics-chords/
# Link:  https://songsinirish.com/slainte-na-n-eanach-lyrics/
# Link:  https://songsinirish.com/slan-agus-beannacht-le-buaireamh-an-tsaoil-lyrics/
# Link:  https://songsinirish.com/slan-le-maigh-lyrics/
# Link:  https://songsinirish.com/slan-leis-an-dun-aengus-lyrics/
# Link:  https://songsinirish.com/sliabh-geal-gcua-na-feile-lyrics/
# Link:  https://songsinirish.com/sliabh-liag-lyrics/
# Link:  https://songsinirish.com/sliabh-na-mban-lyrics/
# Link:  https://songsinirish.com/ta-me-i-mo-shui-lyrics/
# Link:  https://songsinirish.com/ta-na-paipeir-da-saighneail-lyrics/
# Link:  https://songsinirish.com/tailliuir-an-mhagaidh-lyrics/
# Link:  https://songsinirish.com/taim-sinte-ar-do-thuama-lyrics/
# Link:  https://songsinirish.com/taimse-ar-an-mbaile-seo-lyrics/
# Link:  https://songsinirish.com/teampall-na-naomh-lyrics/
# Link:  https://songsinirish.com/teir-abhaile-riu-lyrics/
# Link:  https://songsinirish.com/thiar-i-gconnachta-lyrics/
# Link:  https://songsinirish.com/thiar-i-mbaile-ui-dhomhnaill-lyrics/
# Link:  https://songsinirish.com/thios-i-dteach-an-torraimh-lyrics/
# Link:  https://songsinirish.com/thios-i-dteach-toraimh-teada-lyrics/
# Link:  https://songsinirish.com/thios-i-lar-an-ghleanna-lyrics/
# Link:  https://songsinirish.com/thug-me-ruide-lyrics/
# Link:  https://songsinirish.com/tiocfaidh-an-samhradh-altan-lyrics/
# Link:  https://songsinirish.com/tiocfaidh-an-samhradh-the-cassidys/
# Link:  https://songsinirish.com/tiocfaidh-an-samhradh-lyrics/
# Link:  https://songsinirish.com/togfaidh-me-mo-sheolta-lyrics/
# Link:  https://songsinirish.com/tomas-ban-mac-aogain-lyrics/
# Link:  https://songsinirish.com/tomas-o-fathaigh-lyrics/
# Link:  https://songsinirish.com/torramh-an-bhairille-lyrics/
# Link:  https://songsinirish.com/trasna-na-dtonnta-lyrics/
# Link:  https://songsinirish.com/trathnoinin-o-de-domhnaigh-lyrics/
# Link:  https://songsinirish.com/trathnona-domhnaigh-lyrics/
# Link:  https://songsinirish.com/trucail-pheige-bhreatha-lyrics/
# Link:  https://songsinirish.com/tuireamh-mhic-finin-duibh-lyrics/
# Link:  https://songsinirish.com/tuirse-mo-chroi-lyrics/
# Link:  https://songsinirish.com/uaigneas-na-rinne-lyrics/
# Link:  https://songsinirish.com/uaisle-acla-lyrics/
# Link:  https://songsinirish.com/una-bhan-lyrics/
# Link:  https://songsinirish.com/una-dheas-ni-nia-lyrics/
# Link:  https://songsinirish.com/una-ni-chonchubhair-bhain-lyrics/
# Link:  https://songsinirish.com/upsai-ra-na-ngearaltach-lyrics/
# Link:  https://songsinirish.com/ur-chill-an-chreagain-lyrics/
# Link:  https://songsinirish.com/urchnoc-chein-mhic-cainte-lyrics/
# 468

# %%
## START HERE IF YOU HAVE ALREADY SCRAPED THE DATA
import csv
import pandas as pd
import numpy as np
from nltk.tokenize import RegexpTokenizer
import nltk

# export to csv
#with open('gaeilge_scrape.csv', 'w', newline='', encoding='UTF-8') as f:
#    writer = csv.writer(f)
#    writer.writerows(gaeilge)
    
# import file
gaeilge = []

with open('gaeilge_scrape.csv', 'r', newline='', encoding='UTF-8') as f:
    reader = csv.reader(f)
    for row in reader:
        gaeilge.append(''.join(row))
        
print(gaeilge[0])
print(len(gaeilge))
# Out:
# [' Is a \\"bhean\\" úd thíos ar bhruach an tsrutháin, seoithín seó uil leo leo, Is an dtuigeann tusa fáth mo ghearáin, seoithín seó uil leo leo, Mar is bliain is an lá so a tógadh mé ó mo leannán, seoithín seó uil leo leo, Is do rugadh mé isteach go lios an chnocáin, seoithín seó uil leo leo.   Curfá:  Seoithín, seoithín, seoithín, seoithín, seoithín seó uil leo leo, Seoithín, seoithín, seoithín, seoithín, seoithín seó uil leo leo.  Ag seo anso mo theach mór maiseach, seoithín seó uil leo leo, Is mó leann úr agus leann sean ann, seoithín seó uil leo leo, Is mó mil bhuí agus céir bheach ann, seoithín seó uil leo leo, Is is mó seanduine ar a nasc ann, seoithín seó uil leo leo.   Curfá   Is abair le mo chéile teacht amáireach, seoithín seó uil leo leo, Is an choinneal chéarach i gcúl a dhearnainn’, seoithín seó uil leo leo, Is scian coise duibhe a thabhairt ’na láimh leis, seoithín seó uil leo leo, Is an capall tosaigh a bhualadh sa bhearnain, seoithín seó uil leo leo.   Curfá   An luibh a bhaint ’tá ag doras an leasa, seoithín seó uil leo leo, Mar shúil le Dia go raghainn leis abhaile, seoithín seó, uil leo leo, Nó mura dtige sé ag an tráth san, seoithín seó uil leo leo, Go mbeadsa im bhanríon ar na mná seo, seoithín seó, uil leo leo.   Curfá  ']
# 468

# %%
###################
## DATA CLEANING ##
###################
# create gaeilge stopwords
gaeilge_stopwords = ['nuair','dh', 'mb', 'c', 'e', 'it', 'll', 'mh', 'be', 'at', 'ea', 'he', 'all', 'h', 'm', 'd', 'n', 'b', 't', 'se', 'ne', 'ab', 'g', 'ín', 'ait', 'aí', 'hí', 'cha', 'air', 'os', 'é', 'fá', 'on', 'om', 'id', 'ga', 'hé', 'sea', 'o', 'á', 'as', 'am', 'ó', 'ba', 'na', 'im', 'í', 's', 'a', 'nach', 'gan', 'riamh', 'ariamh', 'chuaigh', 'chuile', 'amuigh', 'dimigh', 'liomsa', 'bhíodh', 'mbíonn', 'ndiaidh', 'istigh', 'cheann', 'thaobh', 'mbeadh', 'bheadh', 'bheith', 'is', 'nó', 'eile', 'idir', 'astu', 'thíos', 'as', 'ár', 'táim', 'bhí', 'aisti', 'chugat', 'orainn', 'anseo', 'déanamh', 'uaithi', 'ná', 'aon', 'suas', 'céanna', 'fúm', 'cathain', 'má', 'bhíothas', 'agaoibh', 'asainn', 'tá', 'chomh', 'tuilleadh', 'fút', 'a', 'éigin', 'freisin', 'ionat', 'fúthu', 'sé', 'muid', 'sna', 'ort', 'níl', 'chuainn', 'tamall', 'níos', 'seo', 'uait', 'beimid', 'leas', 'féin', 'chucu', 'cad', 'libh', 'sinn', 'araon', 'uirthi', 'iad', 'uaim', 'mar', 'beith', 'agam', 'uainn', 'faoi', 'chugam', 'cé', 'de', 'úire', 'trí', 'asat', 'fosta', 'ní', 'ar', 'ionam', 'cá', 'dtí', 'go', 'dhéanamh', 'aici', 'gcarr', 'beidh', 'orm', 'tríd', 'tamaill', 'mise', 'chuige', 'thuas', 'mó', 'leat', 'iontu', 'agat', 'do', 'bhfuil', 'ach', 'cár', 'timpeall', 'taobh', 'inti', 'táthar', 'bhíomar', 'sa', 'anois', 'againn', 'siad', 'chuici', 'táimid', 'fúinn', 'le', 'agus', 'dom', 'isteach', 'i', 'gach', 'cén', 'ansin', 'ann', 'tú', 'leis', 'uair', 'tosach', 'fúibh', 'uaidh', 'amach', 'orthu', 'di', 'duit', 'ionainn', 'in', 'arís', 'siúd', 'bhrí', 'leo', 'é', 'uathu', 'ó', 'carr', 'tusa', 'aige', 'dhiaidh', 'na', 'dóibh', 'an', 'linn', 'síos', 'charr', 'aice', 'acu', 'thar', 'sí', 'léi', 'liom', 'mé', 'mo', 'déanaim', 'chaoi', 'asam', 'dó', 'conas', 'dúinn', 'curfá', 'cúrfa', 'tá', 'ag']

# lowercase, no punctuation, no stop words
gaeilge_clean = []

for song in gaeilge:
    song = song.lower()
    tokenizer = RegexpTokenizer(r'\w+')
    punc_free = tokenizer.tokenize(song)
    stop_free = ' '.join([word for word in punc_free if word not in gaeilge_stopwords])
    gaeilge_clean.append(stop_free)

print(len(gaeilge_clean))
print(gaeilge_clean[0])
# Out:
# 468
# bhean úd bhruach tsrutháin seoithín seó uil dtuigeann fáth ghearáin seoithín seó uil bliain lá so tógadh leannán seoithín seó uil rugadh lios chnocáin seoithín seó uil seoithín seoithín seoithín seoithín seoithín seó uil seoithín seoithín seoithín seoithín seoithín seó uil anso theach mór maiseach seoithín seó uil leann úr leann sean seoithín seó uil mil bhuí céir bheach seoithín seó uil seanduine nasc seoithín seó uil abair chéile teacht amáireach seoithín seó uil choinneal chéarach gcúl dhearnainn seoithín seó uil scian coise duibhe thabhairt láimh seoithín seó uil capall tosaigh bhualadh bhearnain seoithín seó uil luibh bhaint doras leasa seoithín seó uil shúil dia raghainn abhaile seoithín seó uil mura dtige tráth san seoithín seó uil mbeadsa bhanríon mná seoithín seó uil

# %%
# combine all songs
gaeilge_full = ''.join(gaeilge_clean)
print(len(gaeilge_full), ' total characters in corpus')
    
# word tokenize
gaeilge_words = nltk.word_tokenize(gaeilge_full)
print(len(gaeilge_words), ' total words in corpus')

# frequency distribution
dist = nltk.FreqDist(gaeilge_words)
print(len(dist.keys()), ' total unique words in corpus')

# create frequency df
freq_df = pd.DataFrame(columns=['word', 'frequency'])

for word in dist.keys():
    freq_df = freq_df.append({'word': word, 'frequency': dist[word]}, ignore_index=True)

# index frequency df by word
word_df = freq_df.set_index('word')

# words in Irish can have an initial mutation, search for these mutations and replace with nominative form
# Examples:
# cailín = chailín
# abhaile = bhaile, mbaile
# caith = chaith
# máithrín = mháithrín

mutations = ['mb','dt','gc', 'nd', 'ng', 'bp']

for word in word_df.index:
    nom_word = np.NaN
    
    if len(word) >= 2:
        if word[1] == 'h' or word[:2] in mutations or word[:3] == 'bhf':
            if word[1] == 'h':
                nom_word = ''.join([word[:1],word[2:]])
            elif word[:2] in mutations:
                nom_word = word[1:]
            elif word[:3] == 'bhf':
                nom_word = word[2:]

        if not pd.isnull(nom_word):
            if nom_word in word_df.index:
                # add non-nominative forms to nominative word
                word_df.loc[nom_word,'frequency'] = word_df.loc[nom_word,'frequency'] + word_df.loc[word,'frequency']
                # drop non-nominative form
                word_df = word_df.drop(word)
            
print(word_df.head())
print(word_df.shape)
# Out:
# 406346  total characters in corpus
# 61234  total words in corpus
# 12804  total unique words in corpus
#           frequency
# word
# úd               73
# tsrutháin         9
# seoithín         33
# seó              22
# uil              17
# (10791, 1)

# %%
########################
## DATA VISUALIZATION ##
########################

# %matplotlib notebook

import matplotlib.pyplot as plt

# create frequent words df
freqwords = [word for word in word_df.index if len(word) > 3 and word_df['frequency'].loc[word] > 150]

freq_word_df = pd.DataFrame(columns=['word','frequency'])

for word in freqwords:
    freq_word_df = freq_word_df.append({'word': word, 'frequency': word_df.loc[word,'frequency']}, ignore_index=True)

# sort by most frequent to least frequent
freq_word_df = freq_word_df.sort_values(by='frequency')
most_freq = freq_word_df['frequency'].max()

fig, ax = plt.subplots()
hbars = ax.barh(freq_word_df['word'], freq_word_df['frequency'])
ax.set_xlabel('Frequency')
ax.set_yticklabels(freq_word_df['word'])
ax.bar_label(hbars, labels=freq_word_df['frequency'])
ax.set_xlim(right=most_freq + 25) # leave space for labels
ax.set_title('Frequent Words in Sean-Nós Songs on SongsInIrish.com')
plt.show()
plt.savefig('freqwords.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\pangu\AppData\Local\Temp/ipykernel_9492/2961580964.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(freq_word_df['word'])

# %%
# words shared between songs
shared_df = pd.DataFrame()

for word in word_df.index:
    word_count = 0
    total_word_freq = 0
    
    for song in gaeilge_clean:
        word_freq = song.count(word)
        if word_freq > 0:
            word_count = word_count + 1
            total_word_freq = total_word_freq + word_freq
    
    shared_df = shared_df.append({'word': word, 'total songs word appears in': word_count, 'total times word appears': total_word_freq}, ignore_index=True)
    
print(shared_df.head())
print(shared_df.shape)
# Out:
#         word  total songs word appears in  total times word appears
# 0         úd                        115.0                     165.0
# 1  tsrutháin                          2.0                       9.0
# 2   seoithín                          2.0                      33.0
# 3        seó                          2.0                      19.0
# 4        uil                        145.0                     245.0
# (10791, 3)

# %%
most_shared_df = shared_df[shared_df['total songs word appears in'] > 150]
most_shared_df = most_shared_df[most_shared_df['word'].str.len() > 3]
print(most_shared_df.shape)

# sort by most shared to least shared
most_shared_df = most_shared_df.sort_values(by='total songs word appears in')
most_freq = most_shared_df['total times word appears'].max()

fig, ax = plt.subplots()
hbars = ax.barh(most_shared_df['word'], most_shared_df['total songs word appears in'])
ax.set_xlabel('Total Shared Songs')
ax.set_yticklabels(most_shared_df['word'])
ax.bar_label(hbars, labels=most_shared_df['total songs word appears in'])
ax.set_xlim(right=most_freq + 15) # leave space for labels
ax.set_title('Shared Words in Sean-Nós Songs on SongsInIrish.com')
plt.show()
plt.savefig('sharedwords.png')
# Out:
# (19, 3)
# <img src="data:image/png;base64,..." width="800">
# C:\Users\pangu\AppData\Local\Temp/ipykernel_9492/1444003288.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(most_shared_df['word'])

# %%
# frequent word use per song
shared_df['average word use per song'] = shared_df['total times word appears'] / shared_df['total songs word appears in']

repeat_df = shared_df[shared_df['average word use per song'] > 10]
repeat_df = repeat_df[repeat_df['word'].str.len() > 3]
print(repeat_df.shape)

# sort by most freq to least freq
repeat_df = repeat_df.sort_values(by='average word use per song')
most_freq = repeat_df['average word use per song'].max()

fig, ax = plt.subplots()
hbars = ax.barh(repeat_df['word'], repeat_df['average word use per song'])
ax.set_xlabel('Average Word Use Per Song')
ax.set_yticklabels(repeat_df['word'])
ax.bar_label(hbars, labels=repeat_df['average word use per song'])
ax.set_xlim(right=most_freq + 15) # leave space for labels
ax.set_title('Average Repetition in Sean-Nós Songs on SongsInIrish.com')
plt.show()
plt.savefig('repeatwords.png')
# Out:
# (13, 4)
# <img src="data:image/png;base64,..." width="800">
# C:\Users\pangu\AppData\Local\Temp/ipykernel_9492/1551894283.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(repeat_df['word'])
